# %% [markdown]
# > # CST1510 Programming for data communication and networks
# > # Week 1 Lab – Python Foundations
# <hr style="border:2px solid gray">
#
# This session introduces Python’s core building blocks: variables, data types, and input/output operations. These fundamentals support all later work in this module.
#
# ---
#
# ## Topics
# - Variables and data types (`int`, `float`, `str`, `bool`)
# - Input (`input()`) and output (`print()`), single/double quotes and escape sequences
# - Comments and basic Python syntax (PEP8 naming)
# - Numeric and augmented assignment operators
# - Built-in functions (`type`, `len`, `round`, `min`, `max`, `sum`)
# - Importing simple built-in modules
#
# ---
#
# ## Lab Structure
# Tasks are grouped by difficulty:
# - **Threshold** – essential skills
# - **Typical** – applied tasks
# - **Excellent** – extended challenges
# - **Stretch (Optional)** – enrichment problems
#
# At the end, select 1–2 tasks for your portfolio.

# %% [markdown]
# ## Problem-Solving & Pseudocode (Brief)
#
# 1. **Inputs/Outputs** – identify required inputs (types/units) and desired outputs (format/precision).
# 2. **Steps** – list actions in order: read → convert → compute → display.
# 3. **Translate** – convert each step to code with clear variable names and f-strings.
# 4. **Test** – try typical and edge values; verify units and formatting.
#
# **Worked example – Rectangle calculator**
#
# - Inputs: width, height (numbers)
# - Outputs: area and perimeter (2 d.p.)
#
# ```python
# width = float(input("Width: "))
# height = float(input("Height: "))
# area = width * height
# perimeter = 2 * (width + height)
# print(f"Area = {area:.2f}")
# print(f"Perimeter = {perimeter:.2f}")
# ```

# %% [markdown]
# # Threshold Tasks

# %% [markdown]
# ### Threshold 1. Questionnaire
#
# Write a program that asks for name, interest, nationality, course, and programming experience, then prints a formatted summary using escape sequences (`\n`, `\t`).
#
# **Example Output:**
# ```
# User Information:
# 	Name: Alice
# 	Interest: Security
# 	Nationality: UK
# 	Course: Cyber
# 	Experience: Beginner
# ```

# %%
# Your code here
n=input('Enter your Name:')
i=input('Enter your Interests:')
na=input('Enter your Nationality:')
c=input('Enter your Course:')
e=input('Enter your Experience:')
print('User Information:\n\t','Name:',n,'\n\t','Interests:',i,'\n\t','Nationality:',na,'\n\t','Course:',c,'\n\t','Experience:',e)
# Out:
# Enter your Name: Alice
# Enter your Interests: Security
# Enter your Nationality: UK
# Enter your Course: Cyber
# Enter your Experience: Beginner
# User Information:
# 	 Name: Alice
# 	 Interests: Security
# 	 Nationality: UK
# 	 Course: Cyber
# 	 Experience: Beginner

# %% [markdown]
# ### Threshold 2. Rectangle Area & Perimeter
#
# Calculate and print the area and perimeter of a rectangle using fixed values: width = 4.5 and height = 7.9.
# Formulas: `area = width * height`, `perimeter = 2 * (width + height)`.
#
# **Example Output:**
# ```
# Area = 35.55
# Perimeter = 24.80
# ```

# %%
# Your code here
W=4.5
h=7.9
area=W*h
perimeter=2*area
print(' Area=',area,'\n','Perimeter',perimeter)
# Out:
#  Area= 35.550000000000004
#  Perimeter 71.10000000000001

# %% [markdown]
# ### Threshold 3. Convert Pounds to Kilograms
#
# Ask the user for a value in pounds, convert to kilograms using `1 lb = 0.454 kg`, and print the result.
#
# **Example Output:**
# ```
# 55.5 pounds is 25.197 kilograms
# ```

# %%
# Your code here
lb=int(input('Enter any value in pounds to be converted to kilograms:'))
k=lb*0.454
print(lb,'pounds is ',k,' kilograms')
# Out:
# Enter any value in pounds to be converted to kilograms: 55
# 55 pounds is   24.970000000000002  kilograms

# %% [markdown]
# ### Threshold 4. Convert Feet to Meters
#
# Ask the user for a value in feet, convert to meters using `1 ft = 0.305 m`, and print the result.
#
# **Example Output:**
# ```
# 16.5 feet is 5.0325 meters
# ```

# %%
# Your code here
feet=int(input('Enter any value in feet to be converted to meters:'))
k=feet*0.305
print(feet,'feet is ',k,' meters')
# Out:
# Enter any value in feet to be converted to meters: 16
# 16 feet is  4.88  meters

# %% [markdown]
# ### Quick Check (no code submission)
# - What data type does `input()` return? Use `type(input("x"))` to verify.
# - Show one example of an escape sequence in `print()`.
# - What is the difference between `/` and `//`? Provide a one-line example for each.

# %% [markdown]
# # Typical Tasks

# %% [markdown]
# ### Typical 1. Total Time to Watch a Series
#
# Compute total viewing time (no breaks) for a series:
# - 5 seasons, 10 episodes per season
# - Season 1: 45 minutes 35 seconds per episode
# - Seasons 2–5: 35 minutes 15 seconds per episode
# Display the total as hours, minutes, and seconds.
#
# **Example Output:**
# ```
# Total time: 39h 30m 0s
# ```

# %%
# Your code here
sm=(45*10+35*40)*60
ss=35*10+15*40
tss=sm+ss
hours=tss//3600
minutes=(tss%3600)//60
seconds=tss%60
print('Total Time:',hours,'h',minutes,'m',seconds,'s')
# Out:
# 31 h 5 m 50 s

# %% [markdown]
# ### Typical 2. Savings Projection (3 Years)
#
# Compute final savings after 3 years given:
# - Save £10 every week for 3 years
# - Year 1 bonus: +£20 each week
# - Every 2 weeks: −£0.50 (sister)
# Assume 52 weeks per year; use arithmetic and augmented assignment; no conditionals.
#
# **Example Output:**
# ```
# Final savings after 3 years: £4689.50
# ```

# %%
# Your code here
y=10*52
y1=30*102
s=0.50*26
print('Final savings after 3 years:£',y+y1-s)
# Out:
# Final savings after 3 years:£ 3567.0

# %% [markdown]
# ### Typical 3. Cyber: HTTP Log Composer
#
# Ask for IP, method, path, status, and bytes, then print a single combined log line (Apache-style).
#
# **Example Output:**
# ```
# 192.168.1.10 - "POST /auth" 401 512
# ```

# %%
# Your code here
ip=input('Enter your IP:')
path=input('Enter your Path:')
status=input('Enter your status:')
bytes=input('Enter your bytes:')
print(ip,'-','\"',path,'/',status,'\"',bytes)
# Out:
# Enter your IP: 192.168.1.10
# Enter your Path: POST
# Enter your status: auth
# Enter your bytes: 402 512
# 192.168.1.10 - " POST / auth " 402 512

# %% [markdown]
# ### Typical 4. Data Science: Dataset Metadata
#
# Ask for dataset name, rows, and columns. Print:
# - dataset name in quotes
# - rows and columns
# - total cells (rows × columns)
#
# **Example Output:**
# ```
# "sales.csv"
# Rows: 120
# Columns: 8
# Cells: 960
# ```

# %%
# Your code here
ds=input('Name of Dataset:')
rows=int(input('Enter the number of rows:'))
col=int(input('Enter the number of columns:'))
cells=rows*col
print('\"',ds,'"','\n','Rows:',rows,'\n','Columns:',col,'\n','Cells:',cells)
# Out:
# Name of Dataset: sales
# Enter the number of rows: 3
# Enter the number of columns: 2
# " sales "
#  Rows: 3
#  Columns: 2
#  Cells: 6

# %% [markdown]
# ### Typical 5. IT: INI-style Config Printer
#
# Ask for three `key=value` pairs (via separate prompts) and print them as an INI block with indentation.
#
# **Example Output:**
# ```
# [config]
# 	max_connections = 200
# 	timeout = 30
# 	region = eu-west-2
# ```

# %%
# Your code here
k1=input('Enter a Key:')
v1=input('Enter a Value:')
d1={k1:v1}
k2=input('Enter a Key:')
v2=input('Enter a Value:')
d2={k2:v2}
k3=input('Enter a Key:')
v3=input('Enter a Value:')
d3={k3:v3}
print('[config]','\n',{k1},'=',{v1},'\n',{k2},'=',{v2},'\n',{k3},'=',{v3})
# Out:
# Enter a Key: maxconnec
# Enter a Value: 300
# Enter a Key: timeout
# Enter a Value: 20
# Enter a Key: region
# Enter a Value: eu-east-3
# [config]
#  {'maxconnec'} = {'300'}
#  {'timeout'} = {'20'}
#  {'region'} = {'eu-east-3'}

# %% [markdown]
# # Excellent Tasks

# %% [markdown]
# ### Excellent 1. Cyber: Timestamped Auth Event
#
# Ask for a username and action (e.g., `LOGIN` or `LOGOUT`) and print a timestamped event line.
#
# **Example Output:**
# ```
# [2025-09-17 14:20:15] LOGIN user=alice
# ```
#
#
# *Optional hint:* `from datetime import datetime; datetime.now().strftime(...)`

# %%
# Your code here
from datetime import datetime
user=input('Enter a username:')
action=input('Enter the action(LOGIN/LOGOUT')
print('[',datetime.now().strftime('%Y-%m-%d,%H:%M:%S'),']',action,'user=',user)
# Out:
# Enter a username: alice
# Enter the action(LOGIN/LOGOUT logout
# [ 2025-09-30,09:49:57 ] logout user= alice

# %% [markdown]
# ### Excellent 2. Data Science: Mini Statistics Report
#
# Ask for five numeric values (space-separated). Print the values, total, mean, median, and sample standard deviation.
#
# **Example Output:**
# ```
# Values: 80, 90, 70, 85, 75
# Total = 400.00
# Mean = 80.00
# Median = 80.00
# Std Dev = 7.91
# ```
#
#
# *Optional hint:* `import statistics as stats`

# %%
# Your code here
import statistics as stats
n1=int(input('Enter the first number'))
n2=int(input('Enter the second number:'))
n3=int(input('Enter the third number:'))
n4=int(input('Enter the fourth number:'))
n5=int(input('Enter the fifth number:'))
d=[n1,n2,n3,n4,n5]
print('Values:',d)
print('Total=',sum(d))
print(stats.mean(d))
print(stats.median(d))
print(stats.stdev(d))
# Out:
# Enter the first number 1
# Enter the second number: 2
# Enter the third number: 3
# Enter the fourth number: 4
# Enter the fifth number: 5
# Values: [1, 2, 3, 4, 5]
# Total= 15
# 3
# 3
# 1.5811388300841898

# %% [markdown]
# ### Excellent 3. IT: Path Decomposition Report
#
# Ask for a file or directory path and print its absolute path, parent, name, stem, and suffix.
#
# **Example Output:**
# ```
# Absolute path: /home/user/project/service.log
# Parent: /home/user/project
# Name: service.log
# Stem: service
# Suffix: .log
# ```
#
#
# *Optional hint:* `from pathlib import Path`

# %%
# Your code here
from pathlib import Path
fn=input('Enter a Directory Path')
#unsure on how to go further ahead with this

# %%
from pathlib import Path
inp = input("Enter a path: ")
p = Path(inp).expanduser().resolve()
#...

# %% [markdown]
# ### Excellent 4. System Info Banner
#
# Ask for a hostname and print OS and Python version as a simple banner (one value per line).
#
# **Example Output:**
# ```
# Host: server01
# OS: Linux
# Python: 3.11.5
# ```
#
#
# *Optional hint:* `import platform; platform.system(); platform.python_version()`

# %%
# Your code here
import platform as pf
hn=input('Enter the name of the host')
print('Host:',hn,'\n','OS:',pf.system(),'\n','Python',pf.python_version())
# Out:
# Enter the name of the host server02
# Host: server02
#  OS: Windows
#  Python 3.13.7

# %% [markdown]
# # Stretch

# %% [markdown]
# ### Stretch 1. Sum of First n Integers
#
# Ask for a positive integer `n` and compute the sum `n*(n+1)//2`. Print the result.
#
# **Example Output:**
# ```
# Sum of 1..10 = 55
# ```

# %%
# Your code here
n=int(input('Enter a postive integer:'))
print('Sum of',n,'=',n*(n+1)//2)
# Out:
# Enter a postive integer 2
# Sum of 2 = 3

# %% [markdown]
# ### Stretch 2. Pentagon Area
#
# Ask for the side length `s` and compute the area: `area = 5*s**2 / (4*tan(pi/5))`. Print to 2 d.p.
#
# **Example Output:**
# ```
# Area = 172.05
# ```
#
#
# *Optional hint:* `from math import tan, pi`

# %%
# Your code here
from math import tan,pi
n=int(input('Enter the length of the side:'))
print('Area=',5*n**2/(4*tan(pi/5)))
# Out:
# Enter the length of the side: 2
# Area= 6.881909602355869

# %% [markdown]
# ### Stretch 3. Population Projection (5 Years)
#
# Assume current population is 312032486 and 1 year = 365 days.
# Rates: birth every 7s, death every 13s, immigrant every 45s.
# Compute projected population for each of the next 5 years using integer division (`//`).
#
# **Example Output:**
# ```
# Year 1: 315,xxx,xxx
# ...
# Year 5: ...
# ```
#
#
# *Optional hint:* Compute yearly net change once; then add each year.

# %%
# Your code here
p=312032486
nos=365*24*60*60
b=nos//7
d=nos//13
i=nos//45
y1=p+b+i-d
y2=y1+b+i-d
y3=y2+b+i-d
y4=y3+b+i-d
y5=y4+b+i-d
print('Year 1:',y1,'\n','Year 2:',y2,'\n','Year 3:',y3,'\n','Year 4:',y4,'\n','Year 5:',y5)
# Out:
# Year 1: 314812582
#  Year 2: 317592678
#  Year 3: 320372774
#  Year 4: 323152870
#  Year 5: 325932966

# %% [markdown]
# ### Stretch 4. Payroll Statement
#
# Ask for: employee name, hours worked, hourly rate, federal tax rate, state tax rate.
# Print a formatted payroll slip with gross pay, each deduction, and net pay (2 d.p.).
#
# **Example Output:**
# ```
# Employee: Smith
# Gross pay: £97.50
# Federal withholding: £19.50
# State withholding: £8.78
# Net pay: £69.22
# ```

# %%
# Your code here
n=input('Enter your Name:')
hw=int(input('Enter the hours worked:'))
hr=float(input('Enter the hourly rate:'))
ft=float(input('Enter the federal tax rate:'))
st=float(input('Enter the state tax rate:'))
gp=hw*hr
fw=gp*(ft/100)
sw=gp*(st/100)
np=gp-fw-sw
print('Employee:',n,'\n','Gross Pay:',gp,'\n','Federal Withholding:',fw,'\n','State Withholding:',sw,'\n','Net Pay:',np,'\n')
# Out:
# Enter your Name: John
# Enter the hours worked: 300
# Enter the hourly rate: 15.50
# Enter the federal tax rate: 3
# Enter the state tax rate: 6
# Employee: John
#  Gross Pay: 4650.0
#  Federal Withholding: 139.5
#  State Withholding: 279.0
#  Net Pay: 4231.5

# %% [markdown]
# ---
#
# ## Portfolio
# Select one or two completed activities that best demonstrate this week’s learning. Polish the code (naming, formatting, comments) so you can commit them to Git in later weeks

# %%
#Name-Reuben Mathew Verghese
#MISIS:M01088461
import statistics as stats#Importing the module needed to complete the task
values=[]#creating an empty list to later store values in
for n in range(1,6):
    number=int(input('Enter the '+str(n)+' number:'))#Allows the user to input the 5 values
    values.append(number)#Appending the value to the aforementioned empty list
print('Values:',values)#Prints all the Values seperated by a comma
print('Total=',sum(values))#Prints the Sum of all the values in the list
print('Mean=',stats.mean(values))#Prints the Mean of all the values in the list
print('Median=',stats.median(values))#Prints the Median of all the values in the list
print('Standard Deviation=',stats.stdev(values))#Prints the Standard Deviation of all the values in the list
# Out:
# Enter the 1 number: 1
# Enter the 2 number: 2
# Enter the 3 number: 3
# Enter the 4 number: 4
# Enter the 5 number: 5
# Values: [1, 2, 3, 4, 5]
# Total= 15
# Mean= 3
# Median= 3
# Standard Deviation= 1.5811388300841898
